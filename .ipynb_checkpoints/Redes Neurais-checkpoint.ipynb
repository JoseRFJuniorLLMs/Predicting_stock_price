# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline

from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def model(shape):
    model = Sequential()
    model.add(LSTM(units = 200, return_sequences=True, input_shape=(shape)))
    model.add(Dropout(0.3))
    model.add(LSTM(150, return_sequences=True))
    model.add(Dropout(0.25))
    model.add(LSTM(150, return_sequences=True))
    model.add(Dropout(0.25))
    model.add(LSTM(200))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=tf.keras.optimizers.RMSprop(),
                loss=tf.keras.losses.MeanSquaredError(),
                metrics=['mean_squared_logarithmic_error'])

    return model

# %%
dados = "/content/drive/My Drive/ColabNotebooks/Projetos Portifolio/Prevendo_valor_acoes/itausa.csv"
dados = pd.read_csv(dados)

dados['Date'] = pd.to_datetime(dados['Date'])

dados_nulos = dados[dados['Close'].isnull() == True].index
for i in dados_nulos:
    ope = ((dados['Open'].iloc[i-1] + dados['Open'].iloc[i-1]) / 2)	
    high = ((dados['High'].iloc[i-1] + dados['High'].iloc[i-1]) / 2)	
    low = ((dados['Low'].iloc[i-1] + dados['Low'].iloc[i-1]) / 2)	
    close = ((dados['Close'].iloc[i-1] + dados['Close'].iloc[i-1]) / 2)
    aclose = ((dados['Adj Close'].iloc[i-1] + dados['Adj Close'].iloc[i-1]) / 2)	
    volume = ((dados['Volume'].iloc[i-1] + dados['Volume'].iloc[i-1]) / 2)

    dados['Open'].iloc[i] = ope
    dados['High'].iloc[i] = high
    dados['Low'].iloc[i] = low
    dados['Close'].iloc[i] = close
    dados['Adj Close'].iloc[i] = aclose
    dados['Volume'].iloc[i] = volume

dados.drop(['High', 'Low', 'Open', 'Adj Close'], axis = 1, inplace=True)

listofNum = list(filter(lambda i: i%200==0, [a for a in range(dados.shape[0])]))
x = dados['Date'].iloc[listofNum]
x = x.append(dados['Date'].tail(1))
x = np.array(x)

dados.plot(x='Date', y='Close', figsize=(12,8))   
plt.xticks(x, rotation='vertical')
plt.axes().yaxis.grid()
plt.axes().xaxis.grid()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
date = dados['Date']
x_val = dados[['Close']].values
normalizer = MinMaxScaler(feature_range=(0,1))
x_scaled = normalizer.fit_transform(x_val)
data = pd.DataFrame(x_scaled)
data = pd.concat([date, data], axis=1)
data.columns = ['Date', 'Close']
data.head()
# Out:
#         Date     Close
# 0 2000-01-03  0.024038
# 1 2000-01-04  0.016426
# 2 2000-01-05  0.022436
# 3 2000-01-06  0.023637
# 4 2000-01-07  0.023237

# %%
data.plot(x='Date', y='Close', figsize=(12,8))   
plt.xticks(x, rotation='vertical')
plt.axes().yaxis.grid()
plt.axes().xaxis.grid()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
train = data[dados['Date'] < '2018-03-29'].copy()
valid = data[dados['Date'] >= '2018-03-29'].copy()
train.shape, valid.shape
# Out:
# ((4600, 2), (552, 2))

# %%
train.head()
# Out:
#         Date     Close
# 0 2000-01-03  0.024038
# 1 2000-01-04  0.016426
# 2 2000-01-05  0.022436
# 3 2000-01-06  0.023637
# 4 2000-01-07  0.023237

# %%
listofNum = list(filter(lambda i: i%200==0, [a for a in range(valid.shape[0])]))
x = valid['Date'].iloc[listofNum]
x = x.append(valid['Date'].tail(1))
x = np.array(x)

valid.plot(x='Date', y='Close', figsize=(12,8))   
plt.xticks(x, rotation='vertical')
plt.axes().yaxis.grid()
plt.axes().xaxis.grid()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
predict = []
real = []
for i in range(200, train.shape[0]):
    predict.append(train['Close'].iloc[i-200:i])
    real.append(train['Close'].iloc[i])

predict, real = np.array(predict), np.array(real)
predict = np.reshape(predict, (predict.shape[0], predict.shape[1], 1))

# %%
model = model((predict.shape[1], 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200, 200)          161600
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 200)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200, 150)          210600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 150)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 200, 150)          180600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 150)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 200)               280800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 833,801
# Trainable params: 833,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(filepath='/content/drive/My Drive/ColabNotebooks/Projetos Portifolio/Prevendo_valor_acoes/modelo_final.best.hdf5', save_best_only=True, verbose=1)

# %%
history = model.fit(predict,
                    real,
                    epochs=100,
                    batch_size=32,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0172 - mean_squared_logarithmic_error: 0.0090WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0172 - mean_squared_logarithmic_error: 0.0090
# Epoch 2/100
# 138/138 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_logarithmic_error: 0.0022WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0042 - mean_squared_logarithmic_error: 0.0022
# Epoch 3/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0030 - mean_squared_logarithmic_error: 0.0016WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0030 - mean_squared_logarithmic_error: 0.0016
# Epoch 4/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0023 - mean_squared_logarithmic_error: 0.0012WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0023 - mean_squared_logarithmic_error: 0.0012
# Epoch 5/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0022 - mean_squared_logarithmic_error: 0.0011WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0022 - mean_squared_logarithmic_error: 0.0011
# Epoch 6/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019 - mean_squared_logarithmic_error: 9.8979e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0019 - mean_squared_logarithmic_error: 9.9312e-04
# Epoch 7/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0015 - mean_squared_logarithmic_error: 8.0315e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0015 - mean_squared_logarithmic_error: 8.0117e-04
# Epoch 8/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0016 - mean_squared_logarithmic_error: 8.3603e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 42ms/step - loss: 0.0016 - mean_squared_logarithmic_error: 8.3508e-04
# Epoch 9/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0014 - mean_squared_logarithmic_error: 7.6192e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0014 - mean_squared_logarithmic_error: 7.6399e-04
# Epoch 10/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0014 - mean_squared_logarithmic_error: 7.2392e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0014 - mean_squared_logarithmic_error: 7.2213e-04
# Epoch 11/100
# 138/138 [==============================] - ETA: 0s - loss: 0.0013 - mean_squared_logarithmic_error: 6.6314e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0013 - mean_squared_logarithmic_error: 6.6314e-04
# Epoch 12/100
# 138/138 [==============================] - ETA: 0s - loss: 0.0012 - mean_squared_logarithmic_error: 6.2736e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0012 - mean_squared_logarithmic_error: 6.2736e-04
# Epoch 13/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0011 - mean_squared_logarithmic_error: 6.0867e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0011 - mean_squared_logarithmic_error: 6.0850e-04
# Epoch 14/100
# 138/138 [==============================] - ETA: 0s - loss: 0.0011 - mean_squared_logarithmic_error: 5.9024e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0011 - mean_squared_logarithmic_error: 5.9024e-04
# Epoch 15/100
# 138/138 [==============================] - ETA: 0s - loss: 0.0011 - mean_squared_logarithmic_error: 5.8412e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0011 - mean_squared_logarithmic_error: 5.8412e-04
# Epoch 16/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0011 - mean_squared_logarithmic_error: 5.6195e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 0.0011 - mean_squared_logarithmic_error: 5.6246e-04
# Epoch 17/100
# 137/138 [============================>.] - ETA: 0s - loss: 0.0010 - mean_squared_logarithmic_error: 5.4390e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss:
-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.6998e-04 - mean_squared_logarithmic_error: 2.2288e-04
# Epoch 91/100
# 138/138 [==============================] - ETA: 0s - loss: 3.8242e-04 - mean_squared_logarithmic_error: 2.2888e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.8242e-04 - mean_squared_logarithmic_error: 2.2888e-04
# Epoch 92/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.8534e-04 - mean_squared_logarithmic_error: 2.3224e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.8581e-04 - mean_squared_logarithmic_error: 2.3300e-04
# Epoch 93/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.9497e-04 - mean_squared_logarithmic_error: 2.3612e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.9506e-04 - mean_squared_logarithmic_error: 2.3624e-04
# Epoch 94/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.7071e-04 - mean_squared_logarithmic_error: 2.1701e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7166e-04 - mean_squared_logarithmic_error: 2.1748e-04
# Epoch 95/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.7818e-04 - mean_squared_logarithmic_error: 2.2355e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7822e-04 - mean_squared_logarithmic_error: 2.2357e-04
# Epoch 96/100
# 138/138 [==============================] - ETA: 0s - loss: 3.7377e-04 - mean_squared_logarithmic_error: 2.2347e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7377e-04 - mean_squared_logarithmic_error: 2.2347e-04
# Epoch 97/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.7763e-04 - mean_squared_logarithmic_error: 2.2278e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7713e-04 - mean_squared_logarithmic_error: 2.2239e-04
# Epoch 98/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.9218e-04 - mean_squared_logarithmic_error: 2.2947e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.9157e-04 - mean_squared_logarithmic_error: 2.2916e-04
# Epoch 99/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.7827e-04 - mean_squared_logarithmic_error: 2.2199e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7874e-04 - mean_squared_logarithmic_error: 2.2245e-04
# Epoch 100/100
# 137/138 [============================>.] - ETA: 0s - loss: 3.7493e-04 - mean_squared_logarithmic_error: 2.2728e-04WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 138/138 [==============================] - 6s 43ms/step - loss: 3.7533e-04 - mean_squared_logarithmic_error: 2.2721e-04

# %%
model.save('/content/drive/My Drive/ColabNotebooks/Projetos Portifolio/Prevendo_valor_acoes/pesos_final.h5')

model_json = model.to_json()

with open('/content/drive/My Drive/ColabNotebooks/Projetos Portifolio/Prevendo_valor_acoes/modelo.json', 'w') as json_file:
    json_file.write(model_json)

# %%
plt.figure(figsize=(12, 8))

loss = history.history['loss'] 
epochsloss = range(1, len(loss)+1)

plt.plot(epochsloss, loss, 'ro-', label='Training Loss')
plt.legend()

# %%
real_price_valid = valid['Close'].values
cbase = normalizer.transform(dados[['Close']].values)
cbase = cbase.reshape(-1, 5152)[0]
print(cbase.shape)
# Out:
# (5152,)

# %%
ipt = cbase[len(cbase) - len(valid) - 200:]
ipt = ipt.reshape(-1, 1)
ipt.shape
# Out:
# (752, 1)

# %%
X_valid = []
for i in range(200, ipt.shape[0]):
  X_valid.append(ipt[i-200:i, 0])

X_valid = np.array(X_valid)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %%
predict = model.predict(X_valid)

# %%
predict_f = normalizer.inverse_transform(predict)
valid_f = normalizer.inverse_transform(valid['Close'].values.reshape(-1, 1))

# %%
plt.figure(figsize=(12,8))
plt.plot(predict_f, color='blue')
plt.plot(valid_f, color='red')
plt.axes().yaxis.grid()
plt.axes().xaxis.grid()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.

# %%
print("Erro:",round(np.sqrt(mean_squared_log_error(valid_f, predict_f))*100, 4),"%")
# Out:
# Erro: 3.622 %
